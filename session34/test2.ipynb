# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('input/1CRZW.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (617, 817, 3)

# %%
R, G, B = cv2.split(image)

# %%
R.shape
# Out:
# (617, 817)

# %%
plt.imshow(R, cmap='gray')
plt.show()
